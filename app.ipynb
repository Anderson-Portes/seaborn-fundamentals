# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
planets = sns.load_dataset('planets')
exercise = sns.load_dataset('exercise')
flights = sns.load_dataset('flights')
diamonds = sns.load_dataset('diamonds').sample(10000)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='tip',y='total_bill',data=tips, hue='time',size='size', palette='coolwarm')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(tips['tip'], bins=15, kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.displot(tips['tip'], bins=15, kde=True)
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(x='sex',y='tip', data=tips, palette='YlGnBu')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips, hue='sex', palette='YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='tip',data=tips, hue='sex', dodge=True, palette='coolwarm')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='reg')

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='kde',fill=True)

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='hex')

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue='pclass')
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
titanic.select_dtypes(['number']).corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(titanic.select_dtypes(['number']).corr(), annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.clustermap(iris.drop('species',axis=1))

# %%
sns.countplot(data=titanic,y='sex',hue='alive')
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.boxenplot(data=exercise,x='pulse')
# Out:
# <Axes: xlabel='pulse'>

# %%
sns.violinplot(data=exercise,x='pulse')
# Out:
# <Axes: xlabel='pulse'>

# %%
sns.ecdfplot(data=exercise,x='pulse',hue='diet')
# Out:
# <Axes: xlabel='pulse', ylabel='Proportion'>

# %%
sns.kdeplot(data=exercise,x='pulse',hue='diet')
# Out:
# <Axes: xlabel='pulse', ylabel='Density'>

# %%
sns.lineplot(data=flights,x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.pointplot(data=flights,x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.kdeplot(data=diamonds,x='carat',y='price',fill=True,cmap='mako_r')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.histplot(data=diamonds,x='carat',y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.kdeplot(data=diamonds,x='carat',y='price',cmap='coolwarm')
sns.histplot(data=diamonds,x='carat',y='price',color='red')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.relplot(data=diamonds,x='carat',y='price',col='cut')
# Out:
# c:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
